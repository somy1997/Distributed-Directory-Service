# %%
import rpyc
from rpyc.utils.server import Server, ThreadedServer
from rpyc import async_
from threading import Thread, Lock, RLock
import time
import copy
from collections import deque
import itertools

mt = RLock()
mt2 = RLock()

class Myservice(rpyc.Service):
    def __init__(self):
        self.ls_child = ls_child
        self.child_conn = []
        self.bgthreads = []
        self.func = None
        self.async_objs = []
        self.l = deque(maxlen = 1000)
        self.id_list = deque(maxlen = 1000)
        self.gran = 5
        self.lc = 0
        self.id = 21
        self.counter = 1
        self.finishes = {}
        self.pkt_details = {}
        self.preval = 0
        self.currval = 0
        self.is_shadow = True
        
        for ch in self.ls_child:
            print("Connection Initiated with {}".format(ch[1]))
            c = rpyc.connect(ch[0], ch[1])
            self.child_conn.append(c)
            self.bgthreads.append(rpyc.BgServingThread(c))
        

#         self.sent_packets = []
#         self.peerid = peerid
#         try:
#             self.peer_conn = rpyc.connect(self.peerid[0], self.peerid[1])
#             self.peer_bg = rpyc.BgServingThread(self.peer_conn)
#         except Exception as e:
#             self.is_shadow = False
        
#         print(self.is_shadow)
    
    def exposed_ID(self): 
        return self.id    
    
    def on_finish(self):

        if(len(self.finishes) == (len(self.child_conn) + 1)):
            print("enter")
            print(self.lc)
            while(len(self.l) > self.lc):
                send = self.gran
                if (len(self.l) - self.lc < self.gran):
                    send = len(self.l) - self.lc
                self.pkt_details[str(self.counter)] = (self.lc, send)
                pkt = list(itertools.islice(self.l, self.lc, self.lc+send))
                self.func(self.counter, pkt, self.id, self.ack_func)
                for _ in range(send):
                    self.l.popleft()
                self.counter += 1
                print("on_finish waala {}".format(self.counter))
            self.cb2()
            
#                 self.lc += send
    
#     def pinger(self):
#         while True:
#             self.peer_conn.root.ping_update()
#             time.sleep(2)
            
#     def exposed_ping_update(self):
#         global mt2
#         mt2.acquire()
#         try:
#             self.pflag = 1
#         finally:
#             mt2.release()
            
#     def ping_checker(self):
#         time.sleep(5)
#         while True:
#             mt2.acquire()
#             try:
#                 if(self.pflag):
#                     self.pflag = 0
#                 else:
                    
#             finally:
#                 mt2.release()
#             time.sleep(5)
    
#     def starter(self):
#         th = Thread(self.ping_checker, name = 'Ping Checking')
#         th.start()
            
    def exposed_packet_ack(self, l):
        self.sent_packets.extend(l)
        print(l)
        
    def exposed_print_pkt_list(self):
        print(self.sent_packets)
    
    def ack_func(self, ID):
        print("Ack recieved for packet id {}".format(ID))
        vals = self.pkt_details[str(ID)]
        id_pkt = list(itertools.islice(self.id_list,vals[0],vals[0]+vals[1]))
#         self.peer_conn.root.packet_ack(id_pkt)
    
    
    def cback(self, pkt_id, value, ID, ack_func, fin = False):
        global mt
        mt.acquire()
        try:
            if(fin == True):
                print("fin called by {}".format(ID))
                self.finishes[str(ID)] = True
                self.on_finish()
            else:                
                idl = []
                for _ in range(len(value)):
                    idl.append(ID)
                self.id_list.extend(idl)
                self.l.extend(value)

                if (ID != self.id):
                    ack_func(pkt_id)

                while(len(self.l) - self.lc >= self.gran):
                    send = self.gran
                    self.pkt_details[str(self.counter)] = (self.lc, self.gran)
                    pkt = list(itertools.islice(self.l, self.lc, self.lc+send))
                    self.func(self.counter, pkt, self.id, self.ack_func)
                    for _ in range(send):
                        self.l.popleft()
                        self.id_list.popleft()
                    self.counter += 1
                    print("cback waala {}".format(self.counter))
#                     self.lc += self.gran
            
        except Exception as e:
            print(e)
        finally:
            mt.release()
        return
    
    def on_connect(self, conn):
        print("Connection established with ")
#         print(conn.root.ID())
        
    def on_disconnect(self,conn):
        print("Have a nice day... goodbye")
        
    def exposed_printvals(self):
        print(self.l)
        print(self.id_list)
    
    def local_search(self):
        fn = self.cback
        for j in range(10):
            l = []
            for i in range(200 + 10*j,200 + 10*j + 10):
                l.append(i)


            time.sleep(1)
            print("done " + str(j))
            fn(j, l, self.id, self.ack_func)
            print("sent " + str(j))
        
        fn(None, None, self.id, None, True)   
            
    def exposed_do_a_search(self, func, cb2):
        global mt
        print ('Search Request Recieved')
        self.func = func
        self.cb2 = cb2
#         if(self.is_shadow == False):
#             th = Thread(self.pinger, name = 'Pinging')
#             th.start()
        
        for child in self.child_conn:
            asearch = async_(child.root.do_a_search)
            aobj = asearch(self.cback)
            self.async_objs.append(aobj)

        
        self.local_search()

# %%
ls_child = []
ls_child.append(("localhost", 18850, 11))
ls_child.append(("localhost", 18851, 12))

peerid = ["localhost", 17752]

# %%
t = ThreadedServer(Myservice, port = 18852)
t.start()
# Out:
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851
# True
# Connection established with
# Connection Initiated with 18850
# Connection Initiated with 18851

# %%
d = {}
d['abc'] = 1
d['cde'] = 2

# %%
for key,value in d.items():
    print(key, value)
# Out:
# cde 2
# abc 1

# %%
def f(kl):
    kl[0] = 1

# %%
l = [0,2,3]

# %%
f(l[0:1])

# %%
l
# Out:
# [0, 2, 3]

# %%
s = 3
if (s != 3):
    print(s)

# %%
t = Thread()
